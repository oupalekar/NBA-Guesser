# %%
from nba_api.stats.endpoints import playercareerstats, commonteamyears
from nba_api.stats.static import teams, players
nba_team = teams.get_teams()
player = players.get_inactive_players()
# print(player)
gary_payton = [p for p in player if player['last_name'] == "Durant"][0]
# # print(gary_payton)

gp_id = gary_payton["id"]
# # Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id=gp_id)
career.get_data_frames()[0]

# cty = commonteamyears.CommonTeamYears().get_data_frames()[0]

# print(cty)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/sp/q0zv5kk50fl15kfq2h47c6q80000gn/T/ipykernel_9207/766975969.py in <module>
#       4 player = players.get_players()
#       5 # print(player)
# ----> 6 gary_payton = [p for p in player if player['last_name'] == "Durant"][0]
#       7 # # print(gary_payton)
#       8
#
# /var/folders/sp/q0zv5kk50fl15kfq2h47c6q80000gn/T/ipykernel_9207/766975969.py in <listcomp>(.0)
#       4 player = players.get_players()
#       5 # print(player)
# ----> 6 gary_payton = [p for p in player if player['last_name'] == "Durant"][0]
#       7 # # print(gary_payton)
#       8
#
# TypeError: list indices must be integers or slices, not str

# %%
from nba_api.stats.static import teams, players
nba_team = teams.get_teams()
celtics = [team for team in nba_team if team["abbreviation"] == "BOS"][0]
celtics_id = celtics['id']

from nba_api.stats.endpoints import leaguegamefinder, teamdetails

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
details = teamdetails.TeamDetails(team_id=celtics_id)
# games = gamefinder.get_data_frames()[0]
# games
d = details.get_data_frames()[0]
d
# Out:
#       TEAM_ID ABBREVIATION NICKNAME  YEARFOUNDED    CITY      ARENA  \
# 0  1610612738          BOS  Celtics         1946  Boston  TD Garden
#
#   ARENACAPACITY          OWNER GENERALMANAGER  HEADCOACH DLEAGUEAFFILIATION
# 0         18624  Wyc Grousbeck   Brad Stevens  Ime Udoka      Maine Celtics

# %%
celtics = [team for team in nba_team if team['abbreviation'] == "GSW"][0]
celtics_id = celtics['id']

from nba_api.stats.endpoints import leaguegamefinder, teamdetails

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
details = teamdetails.TeamDetails(team_id=celtics_id)
games = gamefinder.get_data_frames()[0]
games
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0        22022  1610612744               GSW  Golden State Warriors
# 1        22022  1610612744               GSW  Golden State Warriors
# 2        22022  1610612744               GSW  Golden State Warriors
# 3        22022  1610612744               GSW  Golden State Warriors
# 4        22022  1610612744               GSW  Golden State Warriors
# ...        ...         ...               ...                    ...
# 3504     21983  1610612744               GOS  Golden State Warriors
# 3505     21983  1610612744               GOS  Golden State Warriors
# 3506     21983  1610612744               GOS  Golden State Warriors
# 3507     21983  1610612744               GOS  Golden State Warriors
# 3508     21983  1610612744               GOS  Golden State Warriors
#
#          GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 0     1522200074  2022-07-17  GSW vs. WAS  L  201   77  ...   0.667  12.0
# ...

# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203090')
career.get_data_frames()[0]
# Out:
#     PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      203090   2012-13        00  1610612753               ORL        20.0
# 1      203090   2013-14        00  1610612753               ORL        21.0
# 2      203090   2014-15        00  1610612753               ORL        22.0
# 3      203090   2015-16        00  1610612757               POR        23.0
# 4      203090   2016-17        00  1610612757               POR        24.0
# 5      203090   2017-18        00  1610612757               POR        25.0
# 6      203090   2018-19        00  1610612757               POR        26.0
# 7      203090   2019-20        00  1610612746               LAC        27.0
# 8      203090   2019-20        00  1610612752               NYK        27.0
# 9      203090   2019-20        00           0               TOT        27.0
# 10     203090   2020-21        00  1610612748               MIA        28.0
# ...
